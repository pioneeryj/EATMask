# %%
from STUNet_dropout import STUNet_dropout
import torch
pool_op_kernel_sizes = [[2, 2, 2], [2, 2, 2], [2, 2, 2], [2, 2, 2], [1, 1, 1]]
conv_kernel_sizes = [[3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3], [3, 3, 3]]

model_dropout = STUNet_dropout(
    input_channels=1,
    num_classes=1,
    depth=[1, 1, 1, 1, 1, 1],
    dims=[32, 64, 128, 256, 512, 512],
    pool_op_kernel_sizes=pool_op_kernel_sizes,
    conv_kernel_sizes=conv_kernel_sizes,
    enable_deep_supervision=True,
    dropout_ratio=0.5
)

device = torch.device('cuda:1')
pretrained_model = "/home/yoonji/AnatoMask/nnunetv2/training/nnUNetTrainer/variants/pretrain/pretrained_model/large_ep4k.model"  # pretrained weights 경로
pretrained_weights = torch.load(pretrained_model, map_location = device, weights_only=False)
#model_dropout.load_state_dict(pretrained_weights, strict=False)
# Out:
# /home/yoonji/anaconda3/envs/medmask/lib/python3.10/site-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
pretrained_weights['state_dict'].keys()
# Out:
# odict_keys(['conv_blocks_context.0.0.conv1.weight', 'conv_blocks_context.0.0.conv1.bias', 'conv_blocks_context.0.0.norm1.weight', 'conv_blocks_context.0.0.norm1.bias', 'conv_blocks_context.0.0.conv2.weight', 'conv_blocks_context.0.0.conv2.bias', 'conv_blocks_context.0.0.norm2.weight', 'conv_blocks_context.0.0.norm2.bias', 'conv_blocks_context.0.0.conv3.weight', 'conv_blocks_context.0.0.conv3.bias', 'conv_blocks_context.0.1.conv1.weight', 'conv_blocks_context.0.1.conv1.bias', 'conv_blocks_context.0.1.norm1.weight', 'conv_blocks_context.0.1.norm1.bias', 'conv_blocks_context.0.1.conv2.weight', 'conv_blocks_context.0.1.conv2.bias', 'conv_blocks_context.0.1.norm2.weight', 'conv_blocks_context.0.1.norm2.bias', 'conv_blocks_context.1.0.conv1.weight', 'conv_blocks_context.1.0.conv1.bias', 'conv_blocks_context.1.0.norm1.weight', 'conv_blocks_context.1.0.norm1.bias', 'conv_blocks_context.1.0.conv2.weight', 'conv_blocks_context.1.0.conv2.bias', 'conv_blocks_context.1.0.norm2.weight', 'conv_blocks_context.1.0.norm2.bias', 'conv_blocks_context.1.0.conv3.weight', 'conv_blocks_context.1.0.conv3.bias', 'conv_blocks_context.1.1.conv1.weight', 'conv_blocks_context.1.1.conv1.bias', 'conv_blocks_context.1.1.norm1.weight', 'conv_blocks_context.1.1.norm1.bias', 'conv_blocks_context.1.1.conv2.weight', 'conv_blocks_context.1.1.conv2.bias', 'conv_blocks_context.1.1.norm2.weight', 'conv_blocks_context.1.1.norm2.bias', 'conv_blocks_context.2.0.conv1.weight', 'conv_blocks_context.2.0.conv1.bias', 'conv_blocks_context.2.0.norm1.weight', 'conv_blocks_context.2.0.norm1.bias', 'conv_blocks_context.2.0.conv2.weight', 'conv_blocks_context.2.0.conv2.bias', 'conv_blocks_context.2.0.norm2.weight', 'conv_blocks_context.2.0.norm2.bias', 'conv_blocks_context.2.0.conv3.weight', 'conv_blocks_context.2.0.conv3.bias', 'conv_blocks_context.2.1.conv1.weight', 'conv_blocks_context.2.1.conv1.bias', 'conv_blocks_context.2.1.norm1.weight', 'conv_blocks_context.2.1.norm1.bias', 'conv_blocks_context.2.1.conv2.weight', 'conv_blocks_context.2.1.conv2.bias', 'conv_blocks_context.2.1.norm2.weight', 'conv_blocks_context.2.1.norm2.bias', 'conv_blocks_context.3.0.conv1.weight', 'conv_blocks_context.3.0.conv1.bias', 'conv_blocks_context.3.0.norm1.weight', 'conv_blocks_context.3.0.norm1.bias', 'conv_blocks_context.3.0.conv2.weight', 'conv_blocks_context.3.0.conv2.bias', 'conv_blocks_context.3.0.norm2.weight', 'conv_blocks_context.3.0.norm2.bias', 'conv_blocks_context.3.0.conv3.weight', 'conv_blocks_context.3.0.conv3.bias', 'conv_blocks_context.3.1.conv1.weight', 'conv_blocks_context.3.1.conv1.bias', 'conv_blocks_context.3.1.norm1.weight', 'conv_blocks_context.3.1.norm1.bias', 'conv_blocks_context.3.1.conv2.weight', 'conv_blocks_context.3.1.conv2.bias', 'conv_blocks_context.3.1.norm2.weight', 'conv_blocks_context.3.1.norm2.bias', 'conv_blocks_context.4.0.conv1.weight', 'conv_blocks_context.4.0.conv1.bias', 'conv_blocks_context.4.0.norm1.weight', 'conv_blocks_context.4.0.norm1.bias', 'conv_blocks_context.4.0.conv2.weight', 'conv_blocks_context.4.0.conv2.bias', 'conv_blocks_context.4.0.norm2.weight', 'conv_blocks_context.4.0.norm2.bias', 'conv_blocks_context.4.0.conv3.weight', 'conv_blocks_context.4.0.conv3.bias', 'conv_blocks_context.4.1.conv1.weight', 'conv_blocks_context.4.1.conv1.bias', 'conv_blocks_context.4.1.norm1.weight', 'conv_blocks_context.4.1.norm1.bias', 'conv_blocks_context.4.1.conv2.weight', 'conv_blocks_context.4.1.conv2.bias', 'conv_blocks_context.4.1.norm2.weight', 'conv_blocks_context.4.1.norm2.bias', 'conv_blocks_context.5.0.conv1.weight', 'conv_blocks_context.5.0.conv1.bias', 'conv_blocks_context.5.0.norm1.weight', 'conv_blocks_context.5.0.norm1.bias', 'conv_blocks_context.5.0.conv2.weight', 'conv_blocks_context.5.0.conv2.bias', 'conv_blocks_context.5.0.norm2.weight', 'conv_blocks_context.5.0.norm2.bias', 'conv_blocks_context.5.0.conv3.weight', 'conv_blocks_context.5.0.conv3.bias', 'conv_blocks_context.5.1.conv1.weight', 'conv_blocks_context.5.1.conv1.bias', 'conv_bloc ...
